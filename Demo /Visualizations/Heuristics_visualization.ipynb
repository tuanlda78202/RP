# %% [markdown]
# # 1. Data Processing

# %%
# import the libraries 
import numpy as np
import pandas as pd 
from time import time

# %%
def input(filename):
    with open(filename) as f:
        N, D, a, b = [int(x) for x in f.readline().split()]
        F = [[0 for _ in range(D+1)] for _ in range(N+1)]
        for i in range(N):
            d = [int(x) for x in f.readline().split()[:-1]]
            if d:
                F[i][d[0]-1] = 1
    F = np.array(F)
    return N, D, a, b, F


# filename = 'data.txt'
filename = 'data/data-365/dataN50D365.txt'
N, D, a, b, F = input(filename)

# %%
# Check status to apply color for each type of status
def status_color(value):
  if value == "Rest": 
    color = 'Green'
  elif value == "Nigh":
    color = 'Red'
  else:
    color = 'White'
  return 'background-color: %s' % color

# %% [markdown]
# # 2. Optimization

# %%
def select(N, off_today, off_nextday, a, b):
    '''
    :param off_today: number of employees cannot work today
    :param off_nextday: number of employees cannot work on the next day
    :return: z = minimum value of the night shift of an employee
    :return: add = number of employees need to add to suffice the bound
    '''
    z, add = 0, 0
    upper_today = N - off_today - 4*a  # upper bound of the number of employees working today
    lower_today = N - off_today - 4*b

    if upper_today < a or lower_today > b:
        return -1
    else:
        z = max(lower_today, a)

    upper_nextday = N - off_nextday - z - 4*a
    lower_nextday = N - off_nextday - z - 4*b

    if lower_nextday > b:
        z += (lower_nextday - b) # remove redundant employees
    elif upper_nextday < a:
        add = a - upper_nextday  # add employees to suffice the bound
    else:
        add = 0

    if z > b or z < a or add > off_nextday:
        return -1
    else:
        return z, add

# %%
def heuristics(N, D, a, b, F):
    num_night = np.full(N, 0)  # number of night shifts of each employee
    global x

    for j in range(D):
        off_today = np.array(F[:, j][:N])
        off_nextday = np.array(F[:, j+1][:N])

        if j != 0:
            for i in range(N):
                if x[i, j-1, 3] == 1:  # if employee i worked at the night shift on the previous day, then rest today
                    off_today[i] = 1

        # Select the possible minimum number of night shift
        if select(N, sum(off_today), sum(off_nextday), a, b) is False:
            print('No optimal solution found.')
            return -1
        else:
            z, add = select(N, sum(off_today), sum(off_nextday), a, b)
        remain = z - add

        # Assign the employee with minimum number of night shift (and absent on the next day) to today's night shift
        emp_off_nextday = np.array([i for i in range(len(off_nextday)) if off_nextday[i] == 1])
        off_night_nextday = np.array([num_night[i] for i in emp_off_nextday])

        while add > 0:
            emp_index = np.argmin(off_night_nextday)
            x[emp_off_nextday[emp_index], j, 3] = 1
            num_night[emp_off_nextday[emp_index]] += 1  # add 1 employee to today's night shift
            off_today[emp_off_nextday[emp_index]] = 1  # avoid working more than one shift in a day
            add -= 1

        # Assign other employees to the night shift if needed (choose among idle employees for today)
        emp_work_today = np.array([i for i in range(len(off_today)) if off_today[i] != 1])
        work_night_today = np.array([num_night[i] for i in emp_work_today])

        while remain > 0:
            emp_index = np.argmin(work_night_today)
            x[emp_work_today[emp_index], j, 3] = 1
            num_night[emp_work_today[emp_index]] += 1
            off_today[emp_work_today[emp_index]] = 1
            remain -= 1

        # Assign other employees to other shifts of today
        i, k = 0, 0
        while i < N and k < 3:
            if off_today[i] == 0:
                x[i, j, k] = 1
                off_today[i] = 1  # avoid assigning the same employee in a day
                k = (k+1) % 3
            i += 1
    return max(num_night)

# %%
if __name__ == '__main__':
    x = np.full((N, D, 4), 0)  # solution matrix

    start = time()
    res = heuristics(N, D, a, b, F)
    end = time()
    print('The optimal value is:', res)
    print('The optimal solution is:')

    for i in range(N):
        for j in range(D):
            for k in range(4):
                if x[i, j, k] == 1:
                    print(f'Staff {i+1}: works on day {j+1}, at shift {k+1}')

    # print(x)
    print('Total execution time:', end-start)
# Out:
# The optimal value is: 8
# The optimal solution is:
# Staff 1: works on day 1, at shift 4
# Staff 1: works on day 3, at shift 1
# Staff 1: works on day 4, at shift 1
# Staff 1: works on day 5, at shift 1
# Staff 1: works on day 6, at shift 1
# Staff 1: works on day 7, at shift 1
# Staff 1: works on day 8, at shift 1
# Staff 1: works on day 9, at shift 1
# Staff 1: works on day 10, at shift 1
# Staff 1: works on day 11, at shift 1
# Staff 1: works on day 12, at shift 1
# Staff 1: works on day 13, at shift 1
# Staff 1: works on day 14, at shift 1
# Staff 1: works on day 15, at shift 1
# Staff 1: works on day 16, at shift 1
# Staff 1: works on day 17, at shift 1
# Staff 1: works on day 18, at shift 1
# Staff 1: works on day 19, at shift 1
# Staff 1: works on day 20, at shift 1
# Staff 1: works on day 21, at shift 1
# Staff 1: works on day 22, at shift 1
# Staff 1: works on day 23, at shift 1
# Staff 1: works on day 24, at shift 1
# Staff 1: works on day 25, at shift 1
# Staff 1: works on day 26, at shift 1
# Staff 1: works on day 27, at shift 1
# Staff 1: works on day 28, at shift 1
# Staff 1: works on day 29, at shift 1
# Staff 1: works on day 30, at shift 1
# Staff 1: works on day 31, at shift 1
# Staff 1: works on day 32, at shift 1
# Staff 1: works on day 33, at shift 1
# Staff 1: works on day 34, at shift 1
# Staff 1: works on day 35, at shift 1
# Staff 1: works on day 36, at shift 1
# Staff 1: works on day 37, at shift 1
# Staff 1: works on day 38, at shift 1
# Staff 1: works on day 39, at shift 1
# Staff 1: works on day 40, at shift 1
# Staff 1: works on day 41, at shift 1
# Staff 1: works on day 42, at shift 1
# Staff 1: works on day 43, at shift 1
# Staff 1: works on day 44, at shift 1
# Staff 1: works on day 45, at shift 1
# Staff 1: works on day 46, at shift 1
# Staff 1: works on day 47, at shift 1
# Staff 1: works on day 48, at shift 1
# Staff 1: works on day 49, at shift 1
# Staff 1: works on day 50, at shift 1
# Staff 1: works on day 51, at shift 4
# Staff 1: works on day 53, at shift 1
# Staff 1: works on day 54, at shift 1
# Staff 1: works on day 55, at shift 1
# Staff 1: works on day 56, at shift 1
# Staff 1: works on day 57, at shift 1
# Staff 1: works on day 58, at shift 1
# Staff 1: works on day 59, at shift 1
# Staff 1: works on day 60, at shift 1
# Staff 1: works on day 61, at shift 1
# Staff 1: works on day 62, at shift 1
# Staff 1: works on day 63, at shift 1
# Staff 1: works on day 64, at shift 1
# Staff 1: works on day 65, at shift 1
# Staff 1: works on day 66, at shift 1
# Staff 1: works on day 67, at shift 1
# Staff 1: works on day 68, at shift 1
# Staff 1: works on day 69, at shift 1
# Staff 1: works on day 70, at shift 1
# Staff 1: works on day 71, at shift 1
# Staff 1: works on day 72, at shift 1
# Staff 1: works on day 73, at shift 1
# Staff 1: works on day 74, at shift 1
# Staff 1: works on day 75, at shift 1
# Staff 1: works on day 76, at shift 1
# Staff 1: works on day 77, at shift 1
# Staff 1: works on day 78, at shift 1
# Staff 1: works on day 80, at shift 1
# Staff 1: works on day 81, at shift 1
# Staff 1: works on day 82, at shift 1
# Staff 1: works on day 83, at shift 1
# Staff 1: works on day 84, at shift 1
# Staff 1: works on day 85, at shift 1
# Staff 1: works on day 86, at shift 1
# Staff 1: works on day 87, at shift 1
# Staff 1: works on day 88, at shift 1
# Staff 1: works on day 89, at shift 1
# Staff 1: works on day 90, at shift 1
# Staff 1: works on day 91, at shift 1
# Staff 1: works on day 92, at shift 1
# Staff 1: works on day 93, at shift 1
# Staff 1: works on day 94, at shift 1
# Staff 1: works on day 95, at shift 1
# Staff 1: works on day 96, at shift 1
# Staff 1: works on day 97, at shift 1
# Staff 1: works on day 98, at shift 1
# Staff 1: works on day 99, at shift 1
# Staff 1: works on day 100, at shift 1
# Staff 1: works on day 101, at shift 4
# Staff 1: works on day 103, at shift 1
# Staff 1: works on day 104, at shift 1
# Staff 1: works on day 105, at shift 1
# Staff 1: works on day 106, at shift 1
# Staff 1: works on day 107, at shift 1
# Staff 1: works on day 108, at shift 1
# Staff 1: works on day 109, at shift 1
# Staff 1: works on day 110, at shift 1
# Staff 1: works on day 111, at shift 1
# Staff 1: works on day 112, at shift 1
# Staff 1: works on day 113, at shift 1
# Staff 1: works on day 114, at shift 1
# Staff 1: works on day 115, at shift 1
# Staff 1: works on day 116, at shift 1
# Staff 1: works on day 117, at shift 1
# Staff 1: works on day 118, at shift 1
# Staff 1: works on day 119, at shift 1
# Staff 1: works on day 120, at shift 1
# Staff 1: works on day 121, at shift 1
# Staff 1: works on day 122, at shift 1
# Staff 1: works on day 123, at shift 1
# Staff 1: works on day 124, at shift 1
# Staff 1: works on day 125, at shift 1
# Staff 1: works on day 126, at shift 1
# Staff 1: works on day 127, at shift 1
# Staff 1: works on day 128, at shift 1
# Staff 1: works on day 129, at shift 1
# Staff 1: works on day 130, at shift 1
# Staff 1: works on day 131, at shift 1
# Staff 1: works on day 132, at shift 1
# Staff 1: works on day 133, at shift 1
# Staff 1: works on day 134, at shift 1
# Staff 1: works on day 135, at shift 1
# Staff 1: works on day 136, at shift 1
# Staff 1: works on day 137, at shift 1
# Staff 1: works on day 138, at shift 1
# Staff 1: works on day 139, at shift 1
# Staff 1: works on day 140, at shift 1
# Staff 1: works on day 141, at shift 1
# Staff 1: works on day 142, at shift 1
# Staff 1: works on day 143, at shift 1
# Staff 1: works on day 144, at shift 1
# Staff 1: works on day 145, at shift 1
# Staff 1: works on day 146, at shift 1
# Staff 1: works on day 147, at shift 1
# Staff 1: works on day 148, at shift 1
# Staff 1: works on day 149, at shift 1
# Staff 1: works on day 150, at shift 1
# Staff 1: works on day 151, at shift 4
# Staff 1: works on day 153, at shift 1
# Staff 1: works on day 154, at shift 1
# Staff 1: works on day 155, at shift 1
# Staff 1: works on day 156, at shift 1
# Staff 1: works on day 157, at shift 1
# Staff 1: works on day 158, at shift 1
# Staff 1: works on day 159, at shift 1
# Staff 1: works on day 160, at shift 1
# Staff 1: works on day 161, at shift 1
# Staff 1: works on day 162, at shift 1
# Staff 1: works on day 163, at shift 1
# Staff 1: works on day 164, at shift 1
# Staff 1: works on day 165, at shift 1
# Staff 1: works on day 166, at shift 1
# Staff 1: works on day 167, at shift 1
# Staff 1: works on day 168, at shift 1
# Staff 1: works on day 169, at shift 1
# Staff 1: works on day 170, at shift 1
# Staff 1: works on day 171, at shift 1
# Staff 1: works on day 172, at shift 1
# Staff 1: works on day 173, at shift 1
# Staff 1: works on day 174, at shift 1
# Staff 1: works on day 175, at shift 1
# Staff 1: works on day 176, at shift 1
# Staff 1: works on day 177, at shift 1
# Staff 1: works on day 178, at shift 1
# Staff 1: works on day 179, at shift 1
# Staff 1: works on day 180, at shift 1
# Staff 1: works on day 181, at shift 1
# Staff 1: works on day 182, at shift 1
# Staff 1: works on day 183, at shift 1
# Staff 1: works on day 184, at shift 1
# Staff 1: works on day 185, at shift 1
# Staff 1: works on day 186, at shift 1
# Staff 1: works on day 187, at shift 1
# Staff 1: works on day 188, at shift 1
# Staff 1: works on day 189, at shift 1
# Staff 1: works on day 190, at shift 1
# Staff 1: works on day 191, at shift 1
# Staff 1: works on day 192, at shift 1
# Staff 1: works on day 193, at shift 1
# Staff 1: works on day 194, at shift 1
# Staff 1: works on day 195, at shift 1
# Staff 1: works on day 196, at shift 1
# Staff 1: works on day 197, at shift 1
# Staff 1: works on day 198, at shift 1
# Staff 1: works on day 199, at shift 1
# Staff 1: works on day 200, at shift 1
# Staff 1: works on day 201, at shift 4
# Staff 1: works on day 203, at shift 1
# Staff 1: works on day 204, at shift 1
# Staff 1: works on day 205, at shift 1
# Staff 1: works on day 206, at shift 1
# Staff 1: works on day 207, at shift 1
# Staff 1: works on day 208, at shift 1
# Staff 1: works on day 209, at shift 1
# Staff 1: works on day 210, at shift 1
# Staff 1: works on day 211, at shift 1
# Staff 1: works on day 212, at shift 1
# Staff 1: works on day 213, at shift 1
# Staff 1: works on day 214, at shift 1
# Staff 1: works on day 215, at shift 1
# Staff 1: works on day 216, at shift 1
# Staff 1: works on day 217, at shift 1
# Staff 1: works on day 218, at shift 1
# Staff 1: works on day 219, at shift 1
# Staff 1: works on day 220, at shift 1
# Staff 1: works on day 221, at shift 1
# Staff 1: works on day 222, at shift 1
# Staff 1: works on day 223, at shift 1
# Staff 1: works on day 224, at shift 1
# Staff 1: works on day 225, at shift 1
# Staff 1: works on day 226, at shift 1
# Staff 1: works on day 227, at shift 1
# Staff 1: works on day 228, at shift 1
# Staff 1: works on day 229, at shift 1
# Staff 1: works on day 230, at shift 1
# Staff 1: works on day 231, at shift 1
# Staff 1: works on day 232, at shift 1
# Staff 1: works on day 233, at shift 1
# Staff 1: works on day 234, at shift 1
# Staff 1: works on day 235, at shift 1
# Staff 1: works on day 236, at shift 1
# Staff 1: works on day 237, at shift 1
# Staff 1: works on day 238, at shift 1
# Staff 1: works on day 239, at shift 1
# Staff 1: works on day 240, at shift 1
# Staff 1: works on day 241, at shift 1
# Staff 1: works on day 242, at shift 1
# Staff 1: works on day 243, at shift 1
# Staff 1: works on day 244, at shift 1
# Staff 1: works on day 245, at shift 1
# Staff 1: works on day 246, at shift 1
# Staff 1: works on day 247, at shift 1
# Staff 1: works on day 248, at shift 1
# Staff 1: works on day 249, at shift 1
# Staff 1: works on day 250, at shift 1
# Staff 1: works on day 251, at shift 4
# Staff 1: works on day 253, at shift 1
# Staff 1: works on day 254, at shift 1
# Staff 1: works on day 255, at shift 1
# Staff 1: works on day 256, at shift 1
# Staff 1: works on day 257, at shift 1
# Staff 1: works on day 258, at shift 1
# Staff 1: works on day 259, at shift 1
# Staff 1: works on day 260, at shift 1
# Staff 1: works on day 261, at shift 1
# Staff 1: works on day 262, at shift 1
# Staff 1: works on day 263, at shift 1
# Staff 1: works on day 264, at shift 1
# Staff 1: works on day 265, at shift 1
# Staff 1: works on day 266, at shift 1
# Staff 1: works on day 267, at shift 1
# Staff 1: works on day 268, at shift 1
# Staff 1: works on day 269, at shift 1
# Staff 1: works on day 270, at shift 1
# Staff 1: works on day 271, at shift 1
# Staff 1: works on day 272, at shift 1
# Staff 1: works on day 273, at shift 1
# Staff 1: works on day 274, at shift 1
# Staff 1: works on day 275, at shift 1
# Staff 1: works on day 276, at shift 1
# Staff 1: works on day 277, at shift 1
# Staff 1: works on day 278, at shift 1
# Staff 1: works on day 279, at shift 1
# Staff 1: works on day 280, at shift 1
# Staff 1: works on day 281, at shift 1
# Staff 1: works on day 282, at shift 1
# Staff 1: works on day 283, at shift 1
# Staff 1: works on day 284, at shift 1
# Staff 1: works on day 285, at shift 1
# Staff 1: works on day 286, at shift 1
# Staff 1: works on day 287, at shift 1
# Staff 1: works on day 288, at shift 1
# Staff 1: works on day 289, at shift 1
# Staff 1: works on day 290, at shift 1
# Staff 1: works on day 291, at shift 1
# Staff 1: works on day 292, at shift 1
# Staff 1: works on day 293, at shift 1
# Staff 1: works on day 294, at shift 1
# Staff 1: works on day 295, at shift 1
# Staff 1: works on day 296, at shift 1
# Staff 1: works on day 297, at shift 1
# Staff 1: works on day 298, at shift 1
# Staff 1: works on day 299, at shift 1
# Staff 1: works on day 300, at shift 1
# Staff 1: works on day 301, at shift 4
# Staff 1: works on day 303, at shift 1
# Staff 1: works on day 304, at shift 1
# Staff 1: works on day 305, at shift 1
# Staff 1: works on day 306, at shift 1
# Staff 1: works on day 307, at shift 1
# Staff 1: works on day 308, at shift 1
# Staff 1: works on day 309, at shift 1
# Staff 1: works on day 310, at shift 1
# Staff 1: works on day 311, at shift 1
# Staff 1: works on day 312, at shift 1
# Staff 1: works on day 313, at shift 1
# Staff 1: works on day 314, at shift 1
# Staff 1: works on day 315, at shift 1
# Staff 1: works on day 316, at shift 1
# Staff 1: works on day 317, at shift 1
# Staff 1: works on day 318, at shift 1
# Staff 1: works on day 319, at shift 1
# Staff 1: works on day 320, at shift 1
# Staff 1: works on day 321, at shift 1
# Staff 1: works on day 322, at shift 1
# Staff 1: works on day 323, at shift 1
# Staff 1: works on day 324, at shift 1
# Staff 1: works on day 325, at shift 1
# Staff 1: works on day 326, at shift 1
# Staff 1: works on day 327, at shift 1
# Staff 1: works on day 328, at shift 1
# Staff 1: works on day 329, at shift 1
# Staff 1: works on day 330, at shift 1
# Staff 1: works on day 331, at shift 1
# Staff 1: works on day 332, at shift 1
# Staff 1: works on day 333, at shift 1
# Staff 1: works on day 334, at shift 1
# Staff 1: works on day 335, at shift 1
# Staff 1: works on day 336, at shift 1
# Staff 1: works on day 337, at shift 1
# Staff 1: works on day 338, at shift 1
# Staff 1: works on day 339, at shift 1
# Staff 1: works on day 340, at shift 1
# Staff 1: works on day 341, at shift 1
# Staff 1: works on day 342, at shift 1
# Staff 1: works on day 343, at shift 1
# Staff 1: works on day 344, at shift 1
# Staff 1: works on day 345, at shift 1
# Staff 1: works on day 346, at shift 1
# Staff 1: works on day 347, at shift 1
# Staff 1: works on day 348, at shift 1
# Staff 1: works on day 349, at shift 1
# Staff 1: works on day 350, at shift 1
# Staff 1: works on day 351, at shift 4
# Staff 1: works on day 353, at shift 1
# Staff 1: works on day 354, at shift 1
# Staff 1: works on day 355, at shift 1
# Staff 1: works on day 356, at shift 1
# Staff 1: works on day 357, at shift 1
# Staff 1: works on day 358, at shift 1
# Staff 1: works on day 359, at shift 1
# Staff 1: works on day 360, at shift 1
# Staff 1: works on day 361, at shift 1
# Staff 1: works on day 362, at shift 1
# Staff 1: works on day 363, at shift 1
# Staff 1: works on day 364, at shift 1
# Staff 1: works on day 365, at shift 1
# Staff 2: works on day 1, at shift 1
# Staff 2: works on day 2, at shift 4
# Staff 2: works on day 4, at shift 2
# Staff 2: works on day 5, at shift 2
# Staff 2: works on day 6, at shift 2
# Staff 2: works on day 7, at shift 2
# Staff 2: works on day 8, at shift 2
# Staff 2: works on day 9, at shift 2
# Staff 2: works on day 10, at shift 2
# Staff 2: works on day 11, at shift 2
# Staff 2: works on day 12, at shift 2
# Staff 2: works on day 13, at shift 2
# Staff 2: works on day 14, at shift 2
# Staff 2: works on day 15, at shift 2
# Staff 2: works on day 16, at shift 2
# Staff 2: works on day 17, at shift 2
# Staff 2: works on day 18, at shift 2
# Staff 2: works on day 19, at shift 2
# Staff 2: works on day 20, at shift 2
# Staff 2: works on day 21, at shift 2
# Staff 2: works on day 22, at shift 2
# Staff 2: works on day 23, at shift 2
# Staff 2: works on day 24, at shift 2
# Staff 2: works on day 25, at shift 2
# Staff 2: works on day 26, at shift 2
# Staff 2: works on day 28, at shift 2
# Staff 2: works on day 29, at shift 2
# Staff 2: works on day 30, at shift 2
# Staff 2: works on day 31, at shift 2
# Staff 2: works on day 32, at shift 2
# Staff 2: works on day 33, at shift 2
# Staff 2: works on day 34, at shift 2
# Staff 2: works on day 35, at shift 2
# Staff 2: works on day 36, at shift 2
# Staff 2: works on day 37, at shift 2
# Staff 2: works on day 38, at shift 2
# Staff 2: works on day 39, at shift 2
# Staff 2: works on day 40, at shift 2
# Staff 2: works on day 41, at shift 2
# Staff 2: works on day 42, at shift 2
# Staff 2: works on day 43, at shift 2
# Staff 2: works on day 44, at shift 2
# Staff 2: works on day 45, at shift 2
# Staff 2: works on day 46, at shift 2
# Staff 2: works on day 47, at shift 2
# Staff 2: works on day 48, at shift 2
# Staff 2: works on day 49, at shift 2
# Staff 2: works on day 50, at shift 2
# Staff 2: works on day 51, at shift 1
# Staff 2: works on day 52, at shift 4
# Staff 2: works on day 54, at shift 2
# Staff 2: works on day 55, at shift 2
# Staff 2: works on day 56, at shift 2
# Staff 2: works on day 57, at shift 2
# Staff 2: works on day 58, at shift 2
# Staff 2: works on day 59, at shift 2
# Staff 2: works on day 60, at shift 2
# Staff 2: works on day 61, at shift 2
# Staff 2: works on day 62, at shift 2
# Staff 2: works on day 63, at shift 2
# Staff 2: works on day 64, at shift 2
# Staff 2: works on day 65, at shift 2
# Staff 2: works on day 66, at shift 2
# Staff 2: works on day 67, at shift 2
# Staff 2: works on day 68, at shift 2
# Staff 2: works on day 69, at shift 2
# Staff 2: works on day 70, at shift 2
# Staff 2: works on day 71, at shift 2
# Staff 2: works on day 72, at shift 2
# Staff 2: works on day 73, at shift 2
# Staff 2: works on day 74, at shift 2
# Staff 2: works on day 75, at shift 2
# Staff 2: works on day 76, at shift 2
# Staff 2: works on day 77, at shift 2
# Staff 2: works on day 78, at shift 2
# Staff 2: works on day 79, at shift 1
# Staff 2: works on day 80, at shift 2
# Staff 2: works on day 81, at shift 2
# Staff 2: works on day 82, at shift 2
# Staff 2: works on day 83, at shift 2
# Staff 2: works on day 84, at shift 2
# Staff 2: works on day 85, at shift 2
# Staff 2: works on day 86, at shift 2
# Staff 2: works on day 87, at shift 2
# Staff 2: works on day 88, at shift 2
# Staff 2: works on day 89, at shift 2
# Staff 2: works on day 90, at shift 2
# Staff 2: works on day 91, at shift 2
# Staff 2: works on day 92, at shift 2
# Staff 2: works on day 93, at shift 2
# Staff 2: works on day 94, at shift 2
# Staff 2: works on day 95, at shift 2
# Staff 2: works on day 96, at shift 2
# Staff 2: works on day 97, at shift 2
# Staff 2: works on day 98, at shift 2
# Staff 2: works on day 99, at shift 2
# Staff 2: works on day 100, at shift 2
# Staff 2: works on day 101, at shift 1
# Staff 2: works on day 102, at shift 4
# Staff 2: works on day 104, at shift 2
# Staff 2: works on day 105, at shift 2
# Staff 2: works on day 106, at shift 2
# Staff 2: works on day 107, at shift 2
# Staff 2: works on day 108, at shift 2
# Staff 2: works on day 109, at shift 2
# Staff 2: works on day 110, at shift 2
# Staff 2: works on day 111, at shift 2
# Staff 2: works on day 112, at shift 2
# Staff 2: works on day 113, at shift 2
# Staff 2: works on day 114, at shift 2
# Staff 2: works on day 115, at shift 2
# Staff 2: works on day 116, at shift 2
# Staff 2: works on day 117, at shift 2
# Staff 2: works on day 118, at shift 2
# Staff 2: works on day 119, at shift 2
# Staff 2: works on day 120, at shift 2
# Staff 2: works on day 121, at shift 2
# Staff 2: works on day 122, at shift 2
# Staff 2: works on day 123, at shift 2
# Staff 2: works on day 124, at shift 2
# Staff 2: works on day 125, at shift 2
# Staff 2: works on day 126, at shift 2
# Staff 2: works on day 127, at shift 2
# Staff 2: works on day 128, at shift 2
# Staff 2: works on day 129, at shift 2
# Staff 2: works on day 130, at shift 2
# Staff 2: works on day 131, at shift 2
# Staff 2: works on day 132, at shift 2
# Staff 2: works on day 133, at shift 2
# Staff 2: works on day 134, at shift 2
# Staff 2: works on day 135, at shift 2
# Staff 2: works on day 136, at shift 2
# Staff 2: works on day 137, at shift 2
# Staff 2: works on day 138, at shift 2
# Staff 2: works on day 139, at shift 2
# Staff 2: works on day 140, at shift 2
# Staff 2: works on day 141, at shift 2
# Staff 2: works on day 142, at shift 2
# Staff 2: works on day 143, at shift 2
# Staff 2: works on day 144, at shift 2
# Staff 2: works on day 145, at shift 2
# Staff 2: works on day 146, at shift 2
# Staff 2: works on day 147, at shift 2
# Staff 2: works on day 148, at shift 2
# Staff 2: works on day 149, at shift 2
# Staff 2: works on day 150, at shift 2
# Staff 2: works on day 151, at shift 1
# Staff 2: works on day 152, at shift 4
# Staff 2: works on day 154, at shift 2
# Staff 2: works on day 155, at shift 2
# Staff 2: works on day 156, at shift 2
# Staff 2: works on day 157, at shift 2
# Staff 2: works on day 158, at shift 2
# Staff 2: works on day 159, at shift 2
# Staff 2: works on day 160, at shift 2
# Staff 2: works on day 161, at shift 2
# Staff 2: works on day 162, at shift 2
# Staff 2: works on day 163, at shift 2
# Staff 2: works on day 164, at shift 2
# Staff 2: works on day 165, at shift 2
# Staff 2: works on day 166, at shift 2
# Staff 2: works on day 167, at shift 2
# Staff 2: works on day 168, at shift 2
# Staff 2: works on day 169, at shift 2
# Staff 2: works on day 170, at shift 2
# Staff 2: works on day 171, at shift 2
# Staff 2: works on day 172, at shift 2
# Staff 2: works on day 173, at shift 2
# Staff 2: works on day 174, at shift 2
# Staff 2: works on day 175, at shift 2
# Staff 2: works on day 176, at shift 2
# Staff 2: works on day 177, at shift 2
# Staff 2: works on day 178, at shift 2
# Staff 2: works on day 179, at shift 2
# Staff 2: works on day 180, at shift 2
# Staff 2: works on day 181, at shift 2
# Staff 2: works on day 182, at shift 2
# Staff 2: works on day 183, at shift 2
# Staff 2: works on day 184, at shift 2
# Staff 2: works on day 185, at shift 2
# Staff 2: works on day 186, at shift 2
# Staff 2: works on day 187, at shift 2
# Staff 2: works on day 188, at shift 2
# Staff 2: works on day 189, at shift 2
# Staff 2: works on day 190, at shift 2
# Staff 2: works on day 191, at shift 2
# Staff 2: works on day 192, at shift 2
# Staff 2: works on day 193, at shift 2
# Staff 2: works on day 194, at shift 2
# Staff 2: works on day 195, at shift 2
# Staff 2: works on day 196, at shift 2
# Staff 2: works on day 197, at shift 2
# Staff 2: works on day 198, at shift 2
# Staff 2: works on day 199, at shift 2
# Staff 2: works on day 200, at shift 2
# Staff 2: works on day 201, at shift 1
# Staff 2: works on day 202, at shift 4
# Staff 2: works on day 204, at shift 2
# Staff 2: works on day 205, at shift 2
# Staff 2: works on day 206, at shift 2
# Staff 2: works on day 207, at shift 2
# Staff 2: works on day 208, at shift 2
# Staff 2: works on day 209, at shift 2
# Staff 2: works on day 210, at shift 2
# Staff 2: works on day 211, at shift 2
# Staff 2: works on day 212, at shift 2
# Staff 2: works on day 213, at shift 2
# Staff 2: works on day 214, at shift 2
# Staff 2: works on day 215, at shift 2
# Staff 2: works on day 216, at shift 2
# Staff 2: works on day 217, at shift 2
# Staff 2: works on day 218, at shift 2
# Staff 2: works on day 219, at shift 2
# Staff 2: works on day 220, at shift 2
# Staff 2: works on day 221, at shift 2
# Staff 2: works on day 222, at shift 2
# Staff 2: works on day 223, at shift 2
# Staff 2: works on day 224, at shift 2
# Staff 2: works on day 225, at shift 2
# Staff 2: works on day 226, at shift 2
# Staff 2: works on day 227, at shift 2
# Staff 2: works on day 228, at shift 2
# Staff 2: works on day 229, at shift 2
# Staff 2: works on day 230, at shift 2
# Staff 2: works on day 231, at shift 2
# Staff 2: works on day 232, at shift 2
# Staff 2: works on day 233, at shift 2
# Staff 2: works on day 234, at shift 2
# Staff 2: works on day 235, at shift 2
# Staff 2: works on day 236, at shift 2
# Staff 2: works on day 237, at shift 2
# Staff 2: works on day 238, at shift 2
# Staff 2: works on day 239, at shift 2
# Staff 2: works on day 240, at shift 2
# Staff 2: works on day 241, at shift 2
# Staff 2: works on day 242, at shift 2
# Staff 2: works on day 243, at shift 2
# Staff 2: works on day 244, at shift 2
# Staff 2: works on day 245, at shift 2
# Staff 2: works on day 246, at shift 2
# Staff 2: works on day 247, at shift 2
# Staff 2: works on day 248, at shift 2
# Staff 2: works on day 249, at shift 2
# Staff 2: works on day 250, at shift 2
# Staff 2: works on day 251, at shift 1
# Staff 2: works on day 252, at shift 4
# Staff 2: works on day 254, at shift 2
# Staff 2: works on day 255, at shift 2
# Staff 2: works on day 256, at shift 2
# Staff 2: works on day 257, at shift 2
# Staff 2: works on day 258, at shift 2
# Staff 2: works on day 259, at shift 2
# Staff 2: works on day 260, at shift 2
# Staff 2: works on day 261, at shift 2
# Staff 2: works on day 262, at shift 2
# Staff 2: works on day 263, at shift 2
# Staff 2: works on day 264, at shift 2
# Staff 2: works on day 265, at shift 2
# Staff 2: works on day 266, at shift 2
# Staff 2: works on day 267, at shift 2
# Staff 2: works on day 268, at shift 2
# Staff 2: works on day 269, at shift 2
# Staff 2: works on day 270, at shift 2
# Staff 2: works on day 271, at shift 2
# Staff 2: works on day 272, at shift 2
# Staff 2: works on day 273, at shift 2
# Staff 2: works on day 274, at shift 2
# Staff 2: works on day 275, at shift 2
# Staff 2: works on day 276, at shift 2
# Staff 2: works on day 277, at shift 2
# Staff 2: works on day 278, at shift 2
# Staff 2: works on day 279, at shift 2
# Staff 2: works on day 280, at shift 2
# Staff 2: works on day 281, at shift 2
# Staff 2: works on day 282, at shift 2
# Staff 2: works on day 283, at shift 2
# Staff 2: works on day 284, at shift 2
# Staff 2: works on day 285, at shift 2
# Staff 2: works on day 286, at shift 2
# Staff 2: works on day 287, at shift 2
# Staff 2: works on day 288, at shift 2
# Staff 2: works on day 289, at shift 2
# Staff 2: works on day 290, at shift 2
# Staff 2: works on day 291, at shift 2
# Staff 2: works on day 292, at shift 2
# Staff 2: works on day 293, at shift 2
# Staff 2: works on day 294, at shift 2
# Staff 2: works on day 295, at shift 2
# Staff 2: works on day 296, at shift 2
# Staff 2: works on day 297, at shift 2
# Staff 2: works on day 298, at shift 2
# Staff 2: works on day 299, at shift 2
# Staff 2: works on day 300, at shift 2
# Staff 2: works on day 301, at shift 1
# Staff 2: works on day 302, at shift 4
# Staff 2: works on day 304, at shift 2
# Staff 2: works on day 305, at shift 2
# Staff 2: works on day 306, at shift 2
# Staff 2: works on day 307, at shift 2
# Staff 2: works on day 308, at shift 2
# Staff 2: works on day 309, at shift 2
# Staff 2: works on day 310, at shift 2
# Staff 2: works on day 311, at shift 2
# Staff 2: works on day 312, at shift 2
# Staff 2: works on day 313, at shift 2
# Staff 2: works on day 314, at shift 2
# Staff 2: works on day 315, at shift 2
# Staff 2: works on day 316, at shift 2
# Staff 2: works on day 317, at shift 2
# Staff 2: works on day 318, at shift 2
# Staff 2: works on day 319, at shift 2
# Staff 2: works on day 320, at shift 2
# Staff 2: works on day 321, at shift 2
# Staff 2: works on day 322, at shift 2
# Staff 2: works on day 323, at shift 2
# Staff 2: works on day 324, at shift 2
# Staff 2: works on day 325, at shift 2
# Staff 2: works on day 326, at shift 2
# Staff 2: works on day 327, at shift 2
# Staff 2: works on day 328, at shift 2
# Staff 2: works on day 329, at shift 2
# Staff 2: works on day 330, at shift 2
# Staff 2: works on day 331, at shift 2
# Staff 2: works on day 332, at shift 2
# Staff 2: works on day 333, at shift 2
# Staff 2: works on day 334, at shift 2
# Staff 2: works on day 335, at shift 2
# Staff 2: works on day 336, at shift 2
# Staff 2: works on day 337, at shift 2
# Staff 2: works on day 338, at shift 2
# Staff 2: works on day 339, at shift 2
# Staff 2: works on day 340, at shift 2
# Staff 2: works on day 341, at shift 2
# Staff 2: works on day 342, at shift 2
# Staff 2: works on day 343, at shift 2
# Staff 2: works on day 344, at shift 2
# Staff 2: works on day 345, at shift 2
# Staff 2: works on day 346, at shift 2
# Staff 2: works on day 347, at shift 2
# Staff 2: works on day 348, at shift 2
# Staff 2: works on day 349, at shift 2
# Staff 2: works on day 350, at shift 2
# Staff 2: works on day 351, at shift 1
# Staff 2: works on day 352, at shift 4
# Staff 2: works on day 354, at shift 2
# Staff 2: works on day 355, at shift 2
# Staff 2: works on day 356, at shift 2
# Staff 2: works on day 357, at shift 2
# Staff 2: works on day 358, at shift 2
# Staff 2: works on day 359, at shift 2
# Staff 2: works on day 360, at shift 2
# Staff 2: works on day 361, at shift 2
# Staff 2: works on day 362, at shift 2
# Staff 2: works on day 363, at shift 2
# Staff 2: works on day 364, at shift 2
# Staff 2: works on day 365, at shift 2
# Staff 3: works on day 1, at shift 2
# Staff 3: works on day 2, at shift 1
# Staff 3: works on day 3, at shift 4
# Staff 3: works on day 5, at shift 3
# Staff 3: works on day 6, at shift 3
# Staff 3: works on day 7, at shift 3
# Staff 3: works on day 8, at shift 3
# Staff 3: works on day 9, at shift 3
# Staff 3: works on day 10, at shift 3
# Staff 3: works on day 11, at shift 3
# Staff 3: works on day 12, at shift 3
# Staff 3: works on day 13, at shift 3
# Staff 3: works on day 14, at shift 3
# Staff 3: works on day 15, at shift 3
# Staff 3: works on day 16, at shift 3
# Staff 3: works on day 17, at shift 3
# Staff 3: works on day 18, at shift 3
# Staff 3: works on day 19, at shift 3
# Staff 3: works on day 20, at shift 3
# Staff 3: works on day 21, at shift 3
# Staff 3: works on day 22, at shift 3
# Staff 3: works on day 23, at shift 3
# Staff 3: works on day 24, at shift 3
# Staff 3: works on day 25, at shift 3
# Staff 3: works on day 26, at shift 3
# Staff 3: works on day 27, at shift 2
# Staff 3: works on day 28, at shift 3
# Staff 3: works on day 29, at shift 3
# Staff 3: works on day 30, at shift 3
# Staff 3: works on day 31, at shift 3
# Staff 3: works on day 32, at shift 3
# Staff 3: works on day 33, at shift 3
# Staff 3: works on day 34, at shift 3
# Staff 3: works on day 35, at shift 3
# Staff 3: works on day 36, at shift 3
# Staff 3: works on day 37, at shift 3
# Staff 3: works on day 38, at shift 3
# Staff 3: works on day 39, at shift 3
# Staff 3: works on day 40, at shift 3
# Staff 3: works on day 41, at shift 3
# Staff 3: works on day 42, at shift 3
# Staff 3: works on day 43, at shift 3
# Staff 3: works on day 44, at shift 3
# Staff 3: works on day 45, at shift 3
# Staff 3: works on day 46, at shift 3
# Staff 3: works on day 47, at shift 3
# Staff 3: works on day 48, at shift 3
# Staff 3: works on day 49, at shift 3
# Staff 3: works on day 50, at shift 3
# Staff 3: works on day 51, at shift 2
# Staff 3: works on day 52, at shift 1
# Staff 3: works on day 53, at shift 4
# Staff 3: works on day 55, at shift 3
# Staff 3: works on day 56, at shift 3
# Staff 3: works on day 57, at shift 3
# Staff 3: works on day 58, at shift 3
# Staff 3: works on day 59, at shift 3
# Staff 3: works on day 60, at shift 3
# Staff 3: works on day 61, at shift 3
# Staff 3: works on day 62, at shift 3
# Staff 3: works on day 63, at shift 3
# Staff 3: works on day 64, at shift 3
# Staff 3: works on day 65, at shift 3
# Staff 3: works on day 66, at shift 3
# Staff 3: works on day 67, at shift 3
# Staff 3: works on day 68, at shift 3
# Staff 3: works on day 69, at shift 3
# Staff 3: works on day 70, at shift 3
# Staff 3: works on day 71, at shift 3
# Staff 3: works on day 72, at shift 3
# Staff 3: works on day 73, at shift 3
# Staff 3: works on day 74, at shift 3
# Staff 3: works on day 75, at shift 3
# Staff 3: works on day 76, at shift 3
# Staff 3: works on day 77, at shift 3
# Staff 3: works on day 78, at shift 3
# Staff 3: works on day 79, at shift 2
# Staff 3: works on day 80, at shift 3
# Staff 3: works on day 81, at shift 3
# Staff 3: works on day 82, at shift 3
# Staff 3: works on day 83, at shift 3
# Staff 3: works on day 85, at shift 3
# Staff 3: works on day 86, at shift 3
# Staff 3: works on day 87, at shift 3
# Staff 3: works on day 88, at shift 3
# Staff 3: works on day 89, at shift 3
# Staff 3: works on day 90, at shift 3
# Staff 3: works on day 91, at shift 3
# Staff 3: works on day 92, at shift 3
# Staff 3: works on day 93, at shift 3
# Staff 3: works on day 94, at shift 3
# Staff 3: works on day 95, at shift 3
# Staff 3: works on day 96, at shift 3
# Staff 3: works on day 97, at shift 3
# Staff 3: works on day 98, at shift 3
# Staff 3: works on day 99, at shift 3
# Staff 3: works on day 100, at shift 3
# Staff 3: works on day 101, at shift 2
# Staff 3: works on day 102, at shift 1
# Staff 3: works on day 103, at shift 4
# Staff 3: works on day 105, at shift 3
# Staff 3: works on day 106, at shift 3
# Staff 3: works on day 107, at shift 3
# Staff 3: works on day 108, at shift 3
# Staff 3: works on day 109, at shift 3
# Staff 3: works on day 110, at shift 3
# Staff 3: works on day 111, at shift 3
# Staff 3: works on day 112, at shift 3
# Staff 3: works on day 113, at shift 3
# Staff 3: works on day 114, at shift 3
# Staff 3: works on day 115, at shift 3
# Staff 3: works on day 116, at shift 3
# Staff 3: works on day 117, at shift 3
# Staff 3: works on day 118, at shift 3
# Staff 3: works on day 119, at shift 3
# Staff 3: works on day 120, at shift 3
# Staff 3: works on day 121, at shift 3
# Staff 3: works on day 122, at shift 3
# Staff 3: works on day 123, at shift 3
# Staff 3: works on day 124, at shift 3
# Staff 3: works on day 125, at shift 3
# Staff 3: works on day 126, at shift 3
# Staff 3: works on day 127, at shift 3
# Staff 3: works on day 128, at shift 3
# Staff 3: works on day 129, at shift 3
# Staff 3: works on day 130, at shift 3
# Staff 3: works on day 131, at shift 3
# Staff 3: works on day 132, at shift 3
# Staff 3: works on day 133, at shift 3
# Staff 3: works on day 134, at shift 3
# Staff 3: works on day 135, at shift 3
# Staff 3: works on day 136, at shift 3
# Staff 3: works on day 137, at shift 3
# Staff 3: works on day 138, at shift 3
# Staff 3: works on day 139, at shift 3
# Staff 3: works on day 140, at shift 3
# Staff 3: works on day 141, at shift 3
# Staff 3: works on day 142, at shift 3
# Staff 3: works on day 143, at shift 3
# Staff 3: works on day 144, at shift 3
# Staff 3: works on day 145, at shift 3
# Staff 3: works on day 146, at shift 3
# Staff 3: works on day 147, at shift 3
# Staff 3: works on day 148, at shift 3
# Staff 3: works on day 149, at shift 3
# Staff 3: works on day 150, at shift 3
# Staff 3: works on day 151, at shift 2
# Staff 3: works on day 152, at shift 1
# Staff 3: works on day 153, at shift 4
# Staff 3: works on day 155, at shift 3
# Staff 3: works on day 156, at shift 3
# Staff 3: works on day 157, at shift 3
# Staff 3: works on day 158, at shift 3
# Staff 3: works on day 159, at shift 3
# Staff 3: works on day 160, at shift 3
# Staff 3: works on day 161, at shift 3
# Staff 3: works on day 162, at shift 3
# Staff 3: works on day 163, at shift 3
# Staff 3: works on day 164, at shift 3
# Staff 3: works on day 165, at shift 3
# Staff 3: works on day 166, at shift 3
# Staff 3: works on day 167, at shift 3
# Staff 3: works on day 168, at shift 3
# Staff 3: works on day 169, at shift 3
# Staff 3: works on day 170, at shift 3
# Staff 3: works on day 171, at shift 3
# Staff 3: works on day 172, at shift 3
# Staff 3: works on day 173, at shift 3
# Staff 3: works on day 174, at shift 3
# Staff 3: works on day 175, at shift 3
# Staff 3: works on day 176, at shift 3
# Staff 3: works on day 177, at shift 3
# Staff 3: works on day 178, at shift 3
# Staff 3: works on day 179, at shift 3
# Staff 3: works on day 180, at shift 3
# Staff 3: works on day 181, at shift 3
# Staff 3: works on day 182, at shift 3
# Staff 3: works on day 183, at shift 3
# Staff 3: works on day 184, at shift 3
# Staff 3: works on day 185, at shift 3
# Staff 3: works on day 186, at shift 3
# Staff 3: works on day 187, at shift 3
# Staff 3: works on day 188, at shift 3
# Staff 3: works on day 189, at shift 3
# Staff 3: works on day 190, at shift 3
# Staff 3: works on day 191, at shift 3
# Staff 3: works on day 192, at shift 3
# Staff 3: works on day 193, at shift 3
# Staff 3: works on day 194, at shift 3
# Staff 3: works on day 195, at shift 3
# Staff 3: works on day 196, at shift 3
# Staff 3: works on day 197, at shift 3
# Staff 3: works on day 198, at shift 3
# Staff 3: works on day 199, at shift 3
# Staff 3: works on day 200, at shift 3
# Staff 3: works on day 201, at shift 2
# Staff 3: works on day 202, at shift 1
# Staff 3: works on day 203, at shift 4
# Staff 3: works on day 205, at shift 3
# Staff 3: works on day 206, at shift 3
# Staff 3: works on day 207, at shift 3
# Staff 3: works on day 208, at shift 3
# Staff 3: works on day 209, at shift 3
# Staff 3: works on day 210, at shift 3
# Staff 3: works on day 211, at shift 3
# Staff 3: works on day 212, at shift 3
# Staff 3: works on day 213, at shift 3
# Staff 3: works on day 214, at shift 3
# Staff 3: works on day 215, at shift 3
# Staff 3: works on day 216, at shift 3
# Staff 3: works on day 217, at shift 3
# Staff 3: works on day 218, at shift 3
# Staff 3: works on day 219, at shift 3
# Staff 3: works on day 220, at shift 3
# Staff 3: works on day 221, at shift 3
# Staff 3: works on day 222, at shift 3
# Staff 3: works on day 223, at shift 3
# Staff 3: works on day 224, at shift 3
# Staff 3: works on day 225, at shift 3
# Staff 3: works on day 226, at shift 3
# Staff 3: works on day 227, at shift 3
# Staff 3: works on day 228, at shift 3
# Staff 3: works on day 229, at shift 3
# Staff 3: works on day 230, at shift 3
# Staff 3: works on day 231, at shift 3
# Staff 3: works on day 232, at shift 3
# Staff 3: works on day 233, at shift 3
# Staff 3: works on day 234, at shift 3
# Staff 3: works on day 235, at shift 3
# Staff 3: works on day 236, at shift 3
# Staff 3: works on day 237, at shift 3
# Staff 3: works on day 238, at shift 3
# Staff 3: works on day 239, at shift 3
# Staff 3: works on day 240, at shift 3
# Staff 3: works on day 241, at shift 3
# Staff 3: works on day 242, at shift 3
# Staff 3: works on day 243, at shift 3
# Staff 3: works on day 244, at shift 3
# Staff 3: works on day 245, at shift 3
# Staff 3: works on day 246, at shift 3
# Staff 3: works on day 247, at shift 3
# Staff 3: works on day 248, at shift 3
# Staff 3: works on day 249, at shift 3
# Staff 3: works on day 250, at shift 3
# Staff 3: works on day 251, at shift 2
# Staff 3: works on day 252, at shift 1
# Staff 3: works on day 253, at shift 4
# Staff 3: works on day 255, at shift 3
# Staff 3: works on day 256, at shift 3
# Staff 3: works on day 257, at shift 3
# Staff 3: works on day 258, at shift 3
# Staff 3: works on day 259, at shift 3
# Staff 3: works on day 260, at shift 3
# Staff 3: works on day 261, at shift 3
# Staff 3: works on day 262, at shift 3
# Staff 3: works on day 263, at shift 3
# Staff 3: works on day 264, at shift 3
# Staff 3: works on day 265, at shift 3
# Staff 3: works on day 266, at shift 3
# Staff 3: works on day 267, at shift 3
# Staff 3: works on day 268, at shift 3
# Staff 3: works on day 269, at shift 3
# Staff 3: works on day 270, at shift 3
# Staff 3: works on day 271, at shift 3
# Staff 3: works on day 272, at shift 3
# Staff 3: works on day 273, at shift 3
# Staff 3: works on day 274, at shift 3
# Staff 3: works on day 275, at shift 3
# Staff 3: works on day 276, at shift 3
# Staff 3: works on day 277, at shift 3
# Staff 3: works on day 278, at shift 3
# Staff 3: works on day 279, at shift 3
# Staff 3: works on day 280, at shift 3
# Staff 3: works on day 281, at shift 3
# Staff 3: works on day 282, at shift 3
# Staff 3: works on day 283, at shift 3
# Staff 3: works on day 284, at shift 3
# Staff 3: works on day 285, at shift 3
# Staff 3: works on day 286, at shift 3
# Staff 3: works on day 287, at shift 3
# Staff 3: works on day 288, at shift 3
# Staff 3: works on day 289, at shift 3
# Staff 3: works on day 290, at shift 3
# Staff 3: works on day 291, at shift 3
# Staff 3: works on day 292, at shift 3
# Staff 3: works on day 293, at shift 3
# Staff 3: works on day 294, at shift 3
# Staff 3: works on day 295, at shift 3
# Staff 3: works on day 296, at shift 3
# Staff 3: works on day 297, at shift 3
# Staff 3: works on day 298, at shift 3
# Staff 3: works on day 299, at shift 3
# Staff 3: works on day 300, at shift 3
# Staff 3: works on day 301, at shift 2
# Staff 3: works on day 302, at shift 1
# Staff 3: works on day 303, at shift 4
# Staff 3: works on day 305, at shift 3
# Staff 3: works on day 306, at shift 3
# Staff 3: works on day 307, at shift 3
# Staff 3: works on day 308, at shift 3
# Staff 3: works on day 309, at shift 3
# Staff 3: works on day 310, at shift 3
# Staff 3: works on day 311, at shift 3
# Staff 3: works on day 312, at shift 3
# Staff 3: works on day 313, at shift 3
# Staff 3: works on day 314, at shift 3
# Staff 3: works on day 315, at shift 3
# Staff 3: works on day 316, at shift 3
# Staff 3: works on day 317, at shift 3
# Staff 3: works on day 318, at shift 3
# Staff 3: works on day 319, at shift 3
# Staff 3: works on day 320, at shift 3
# Staff 3: works on day 321, at shift 3
# Staff 3: works on day 322, at shift 3
# Staff 3: works on day 323, at shift 3
# Staff 3: works on day 324, at shift 3
# Staff 3: works on day 325, at shift 3
# Staff 3: works on day 326, at shift 3
# Staff 3: works on day 327, at shift 3
# Staff 3: works on day 328, at shift 3
# Staff 3: works on day 329, at shift 3
# Staff 3: works on day 330, at shift 3
# Staff 3: works on day 331, at shift 3
# Staff 3: works on day 332, at shift 3
# Staff 3: works on day 333, at shift 3
# Staff 3: works on day 334, at shift 3
# Staff 3: works on day 335, at shift 3
# Staff 3: works on day 336, at shift 3
# Staff 3: works on day 337, at shift 3
# Staff 3: works on day 338, at shift 3
# Staff 3: works on day 339, at shift 3
# Staff 3: works on day 340, at shift 3
# Staff 3: works on day 341, at shift 3
# Staff 3: works on day 342, at shift 3
# Staff 3: works on day 343, at shift 3
# Staff 3: works on day 344, at shift 3
# Staff 3: works on day 345, at shift 3
# Staff 3: works on day 346, at shift 3
# Staff 3: works on day 347, at shift 3
# Staff 3: works on day 348, at shift 3
# Staff 3: works on day 349, at shift 3
# Staff 3: works on day 350, at shift 3
# Staff 3: works on day 351, at shift 2
# Staff 3: works on day 352, at shift 1
# Staff 3: works on day 353, at shift 4
# Staff 3: works on day 355, at shift 3
# Staff 3: works on day 356, at shift 3
# Staff 3: works on day 357, at shift 3
# Staff 3: works on day 358, at shift 3
# Staff 3: works on day 359, at shift 3
# Staff 3: works on day 360, at shift 3
# Staff 3: works on day 361, at shift 3
# Staff 3: works on day 362, at shift 3
# Staff 3: works on day 363, at shift 3
# Staff 3: works on day 364, at shift 3
# Staff 3: works on day 365, at shift 3
# Staff 4: works on day 1, at shift 3
# Staff 4: works on day 2, at shift 2
# Staff 4: works on day 3, at shift 2
# Staff 4: works on day 4, at shift 4
# Staff 4: works on day 6, at shift 1
# Staff 4: works on day 7, at shift 1
# Staff 4: works on day 8, at shift 1
# Staff 4: works on day 9, at shift 1
# Staff 4: works on day 10, at shift 1
# Staff 4: works on day 11, at shift 1
# Staff 4: works on day 12, at shift 1
# Staff 4: works on day 13, at shift 1
# Staff 4: works on day 14, at shift 1
# Staff 4: works on day 15, at shift 1
# Staff 4: works on day 16, at shift 1
# Staff 4: works on day 17, at shift 1
# Staff 4: works on day 18, at shift 1
# Staff 4: works on day 19, at shift 1
# Staff 4: works on day 20, at shift 1
# Staff 4: works on day 21, at shift 1
# Staff 4: works on day 22, at shift 1
# Staff 4: works on day 23, at shift 1
# Staff 4: works on day 24, at shift 1
# Staff 4: works on day 25, at shift 1
# Staff 4: works on day 26, at shift 1
# Staff 4: works on day 27, at shift 3
# Staff 4: works on day 28, at shift 1
# Staff 4: works on day 29, at shift 1
# Staff 4: works on day 30, at shift 1
# Staff 4: works on day 31, at shift 1
# Staff 4: works on day 32, at shift 1
# Staff 4: works on day 33, at shift 1
# Staff 4: works on day 34, at shift 1
# Staff 4: works on day 35, at shift 1
# Staff 4: works on day 36, at shift 1
# Staff 4: works on day 37, at shift 1
# Staff 4: works on day 38, at shift 1
# Staff 4: works on day 39, at shift 1
# Staff 4: works on day 40, at shift 1
# Staff 4: works on day 41, at shift 1
# Staff 4: works on day 42, at shift 1
# Staff 4: works on day 44, at shift 1
# Staff 4: works on day 45, at shift 1
# Staff 4: works on day 46, at shift 1
# Staff 4: works on day 47, at shift 1
# Staff 4: works on day 48, at shift 1
# Staff 4: works on day 49, at shift 1
# Staff 4: works on day 50, at shift 1
# Staff 4: works on day 51, at shift 3
# Staff 4: works on day 52, at shift 2
# Staff 4: works on day 53, at shift 2
# Staff 4: works on day 54, at shift 4
# Staff 4: works on day 56, at shift 1
# Staff 4: works on day 57, at shift 1
# Staff 4: works on day 58, at shift 1
# Staff 4: works on day 59, at shift 1
# Staff 4: works on day 60, at shift 1
# Staff 4: works on day 61, at shift 1
# Staff 4: works on day 62, at shift 1
# Staff 4: works on day 63, at shift 1
# Staff 4: works on day 64, at shift 1
# Staff 4: works on day 65, at shift 1
# Staff 4: works on day 66, at shift 1
# Staff 4: works on day 67, at shift 1
# Staff 4: works on day 68, at shift 1
# Staff 4: works on day 69, at shift 1
# Staff 4: works on day 70, at shift 1
# Staff 4: works on day 71, at shift 1
# Staff 4: works on day 72, at shift 1
# Staff 4: works on day 73, at shift 1
# Staff 4: works on day 74, at shift 1
# Staff 4: works on day 75, at shift 1
# Staff 4: works on day 76, at shift 1
# Staff 4: works on day 77, at shift 1
# Staff 4: works on day 78, at shift 1
# Staff 4: works on day 79, at shift 3
# Staff 4: works on day 80, at shift 1
# Staff 4: works on day 81, at shift 1
# Staff 4: works on day 82, at shift 1
# Staff 4: works on day 83, at shift 1
# Staff 4: works on day 84, at shift 3
# Staff 4: works on day 85, at shift 1
# Staff 4: works on day 86, at shift 1
# Staff 4: works on day 87, at shift 1
# Staff 4: works on day 88, at shift 1
# Staff 4: works on day 89, at shift 1
# Staff 4: works on day 90, at shift 1
# Staff 4: works on day 91, at shift 1
# Staff 4: works on day 92, at shift 1
# Staff 4: works on day 93, at shift 1
# Staff 4: works on day 94, at shift 1
# Staff 4: works on day 95, at shift 1
# Staff 4: works on day 96, at shift 1
# Staff 4: works on day 97, at shift 1
# Staff 4: works on day 98, at shift 1
# Staff 4: works on day 99, at shift 1
# Staff 4: works on day 100, at shift 1
# Staff 4: works on day 101, at shift 3
# Staff 4: works on day 102, at shift 2
# Staff 4: works on day 103, at shift 2
# Staff 4: works on day 104, at shift 4
# Staff 4: works on day 106, at shift 1
# Staff 4: works on day 107, at shift 1
# Staff 4: works on day 108, at shift 1
# Staff 4: works on day 109, at shift 1
# Staff 4: works on day 110, at shift 1
# Staff 4: works on day 111, at shift 1
# Staff 4: works on day 112, at shift 1
# Staff 4: works on day 113, at shift 1
# Staff 4: works on day 114, at shift 1
# Staff 4: works on day 115, at shift 1
# Staff 4: works on day 116, at shift 1
# Staff 4: works on day 117, at shift 1
# Staff 4: works on day 118, at shift 1
# Staff 4: works on day 119, at shift 1
# Staff 4: works on day 120, at shift 1
# Staff 4: works on day 121, at shift 1
# Staff 4: works on day 122, at shift 1
# Staff 4: works on day 123, at shift 1
# Staff 4: works on day 124, at shift 1
# Staff 4: works on day 125, at shift 1
# Staff 4: works on day 126, at shift 1
# Staff 4: works on day 127, at shift 1
# Staff 4: works on day 128, at shift 1
# Staff 4: works on day 129, at shift 1
# Staff 4: works on day 130, at shift 1
# Staff 4: works on day 131, at shift 1
# Staff 4: works on day 132, at shift 1
# Staff 4: works on day 133, at shift 1
# Staff 4: works on day 134, at shift 1
# Staff 4: works on day 135, at shift 1
# Staff 4: works on day 136, at shift 1
# Staff 4: works on day 137, at shift 1
# Staff 4: works on day 138, at shift 1
# Staff 4: works on day 139, at shift 1
# Staff 4: works on day 140, at shift 1
# Staff 4: works on day 141, at shift 1
# Staff 4: works on day 142, at shift 1
# Staff 4: works on day 143, at shift 1
# Staff 4: works on day 144, at shift 1
# Staff 4: works on day 145, at shift 1
# Staff 4: works on day 146, at shift 1
# Staff 4: works on day 147, at shift 1
# Staff 4: works on day 148, at shift 1
# Staff 4: works on day 149, at shift 1
# Staff 4: works on day 150, at shift 1
# Staff 4: works on day 151, at shift 3
# Staff 4: works on day 152, at shift 2
# Staff 4: works on day 153, at shift 2
# Staff 4: works on day 154, at shift 4
# Staff 4: works on day 156, at shift 1
# Staff 4: works on day 157, at shift 1
# Staff 4: works on day 158, at shift 1
# Staff 4: works on day 159, at shift 1
# Staff 4: works on day 160, at shift 1
# Staff 4: works on day 161, at shift 1
# Staff 4: works on day 162, at shift 1
# Staff 4: works on day 163, at shift 1
# Staff 4: works on day 164, at shift 1
# Staff 4: works on day 165, at shift 1
# Staff 4: works on day 166, at shift 1
# Staff 4: works on day 167, at shift 1
# Staff 4: works on day 168, at shift 1
# Staff 4: works on day 169, at shift 1
# Staff 4: works on day 170, at shift 1
# Staff 4: works on day 171, at shift 1
# Staff 4: works on day 172, at shift 1
# Staff 4: works on day 173, at shift 1
# Staff 4: works on day 174, at shift 1
# Staff 4: works on day 175, at shift 1
# Staff 4: works on day 176, at shift 1
# Staff 4: works on day 177, at shift 1
# Staff 4: works on day 178, at shift 1
# Staff 4: works on day 179, at shift 1
# Staff 4: works on day 180, at shift 1
# Staff 4: works on day 181, at shift 1
# Staff 4: works on day 182, at shift 1
# Staff 4: works on day 183, at shift 1
# Staff 4: works on day 184, at shift 1
# Staff 4: works on day 185, at shift 1
# Staff 4: works on day 186, at shift 1
# Staff 4: works on day 187, at shift 1
# Staff 4: works on day 188, at shift 1
# Staff 4: works on day 189, at shift 1
# Staff 4: works on day 190, at shift 1
# Staff 4: works on day 191, at shift 1
# Staff 4: works on day 192, at shift 1
# Staff 4: works on day 193, at shift 1
# Staff 4: works on day 194, at shift 1
# Staff 4: works on day 195, at shift 1
# Staff 4: works on day 196, at shift 1
# Staff 4: works on day 197, at shift 1
# Staff 4: works on day 198, at shift 1
# Staff 4: works on day 199, at shift 1
# Staff 4: works on day 200, at shift 1
# Staff 4: works on day 201, at shift 3
# Staff 4: works on day 202, at shift 2
# Staff 4: works on day 203, at shift 2
# Staff 4: works on day 204, at shift 4
# Staff 4: works on day 206, at shift 1
# Staff 4: works on day 207, at shift 1
# Staff 4: works on day 208, at shift 1
# Staff 4: works on day 209, at shift 1
# Staff 4: works on day 210, at shift 1
# ...
# Staff 49: works on day 311, at shift 2
# Staff 49: works on day 312, at shift 2
# Staff 49: works on day 313, at shift 2
# Staff 49: works on day 314, at shift 2
# Staff 49: works on day 315, at shift 2
# Staff 49: works on day 316, at shift 2
# Staff 49: works on day 317, at shift 2
# Staff 49: works on day 318, at shift 2
# Staff 49: works on day 319, at shift 2
# Staff 49: works on day 320, at shift 2
# Staff 49: works on day 321, at shift 2
# Staff 49: works on day 322, at shift 2
# Staff 49: works on day 323, at shift 2
# Staff 49: works on day 324, at shift 2
# Staff 49: works on day 325, at shift 2
# Staff 49: works on day 326, at shift 2
# Staff 49: works on day 327, at shift 2
# Staff 49: works on day 328, at shift 2
# Staff 49: works on day 329, at shift 2
# Staff 49: works on day 330, at shift 2
# Staff 49: works on day 331, at shift 2
# Staff 49: works on day 332, at shift 2
# Staff 49: works on day 333, at shift 2
# Staff 49: works on day 334, at shift 2
# Staff 49: works on day 335, at shift 2
# Staff 49: works on day 336, at shift 2
# Staff 49: works on day 337, at shift 2
# Staff 49: works on day 338, at shift 2
# Staff 49: works on day 339, at shift 2
# Staff 49: works on day 340, at shift 2
# Staff 49: works on day 341, at shift 2
# Staff 49: works on day 342, at shift 2
# Staff 49: works on day 343, at shift 2
# Staff 49: works on day 344, at shift 2
# Staff 49: works on day 345, at shift 2
# Staff 49: works on day 346, at shift 2
# Staff 49: works on day 347, at shift 2
# Staff 49: works on day 348, at shift 2
# Staff 49: works on day 349, at shift 4
# Staff 49: works on day 351, at shift 3
# Staff 49: works on day 352, at shift 2
# Staff 49: works on day 353, at shift 2
# Staff 49: works on day 354, at shift 2
# Staff 49: works on day 355, at shift 2
# Staff 49: works on day 356, at shift 2
# Staff 49: works on day 357, at shift 2
# Staff 49: works on day 358, at shift 2
# Staff 49: works on day 359, at shift 2
# Staff 49: works on day 360, at shift 2
# Staff 49: works on day 361, at shift 2
# Staff 49: works on day 362, at shift 2
# Staff 49: works on day 363, at shift 2
# Staff 49: works on day 364, at shift 2
# Staff 49: works on day 365, at shift 2
# Staff 50: works on day 1, at shift 1
# Staff 50: works on day 2, at shift 2
# Staff 50: works on day 3, at shift 2
# Staff 50: works on day 4, at shift 2
# Staff 50: works on day 5, at shift 2
# Staff 50: works on day 6, at shift 2
# Staff 50: works on day 7, at shift 3
# Staff 50: works on day 8, at shift 2
# Staff 50: works on day 9, at shift 3
# Staff 50: works on day 10, at shift 2
# Staff 50: works on day 11, at shift 2
# Staff 50: works on day 12, at shift 3
# Staff 50: works on day 13, at shift 2
# Staff 50: works on day 14, at shift 2
# Staff 50: works on day 15, at shift 2
# Staff 50: works on day 16, at shift 2
# Staff 50: works on day 17, at shift 3
# Staff 50: works on day 18, at shift 2
# Staff 50: works on day 19, at shift 2
# Staff 50: works on day 20, at shift 3
# Staff 50: works on day 21, at shift 3
# Staff 50: works on day 22, at shift 3
# Staff 50: works on day 23, at shift 3
# Staff 50: works on day 24, at shift 3
# Staff 50: works on day 25, at shift 3
# Staff 50: works on day 26, at shift 2
# Staff 50: works on day 27, at shift 2
# Staff 50: works on day 28, at shift 2
# Staff 50: works on day 29, at shift 2
# Staff 50: works on day 30, at shift 2
# Staff 50: works on day 31, at shift 2
# Staff 50: works on day 32, at shift 2
# Staff 50: works on day 33, at shift 2
# Staff 50: works on day 34, at shift 3
# Staff 50: works on day 35, at shift 2
# Staff 50: works on day 36, at shift 2
# Staff 50: works on day 37, at shift 3
# Staff 50: works on day 38, at shift 3
# Staff 50: works on day 39, at shift 2
# Staff 50: works on day 40, at shift 2
# Staff 50: works on day 41, at shift 2
# Staff 50: works on day 42, at shift 3
# Staff 50: works on day 43, at shift 2
# Staff 50: works on day 44, at shift 2
# Staff 50: works on day 46, at shift 3
# Staff 50: works on day 47, at shift 3
# Staff 50: works on day 48, at shift 3
# Staff 50: works on day 49, at shift 2
# Staff 50: works on day 50, at shift 4
# Staff 50: works on day 52, at shift 3
# Staff 50: works on day 53, at shift 2
# Staff 50: works on day 54, at shift 3
# Staff 50: works on day 55, at shift 3
# Staff 50: works on day 56, at shift 3
# Staff 50: works on day 57, at shift 3
# Staff 50: works on day 58, at shift 3
# Staff 50: works on day 59, at shift 3
# Staff 50: works on day 60, at shift 3
# Staff 50: works on day 61, at shift 2
# Staff 50: works on day 62, at shift 2
# Staff 50: works on day 63, at shift 3
# Staff 50: works on day 64, at shift 3
# Staff 50: works on day 65, at shift 3
# Staff 50: works on day 66, at shift 3
# Staff 50: works on day 67, at shift 3
# Staff 50: works on day 68, at shift 3
# Staff 50: works on day 69, at shift 2
# Staff 50: works on day 70, at shift 2
# Staff 50: works on day 71, at shift 2
# Staff 50: works on day 72, at shift 3
# Staff 50: works on day 73, at shift 3
# Staff 50: works on day 74, at shift 2
# Staff 50: works on day 75, at shift 2
# Staff 50: works on day 76, at shift 3
# Staff 50: works on day 77, at shift 3
# Staff 50: works on day 78, at shift 3
# Staff 50: works on day 79, at shift 2
# Staff 50: works on day 80, at shift 3
# Staff 50: works on day 81, at shift 3
# Staff 50: works on day 82, at shift 3
# Staff 50: works on day 83, at shift 3
# Staff 50: works on day 84, at shift 2
# Staff 50: works on day 85, at shift 3
# Staff 50: works on day 86, at shift 3
# Staff 50: works on day 87, at shift 3
# Staff 50: works on day 88, at shift 3
# Staff 50: works on day 89, at shift 3
# Staff 50: works on day 90, at shift 3
# Staff 50: works on day 91, at shift 3
# Staff 50: works on day 92, at shift 3
# Staff 50: works on day 93, at shift 3
# Staff 50: works on day 94, at shift 3
# Staff 50: works on day 95, at shift 2
# Staff 50: works on day 96, at shift 3
# Staff 50: works on day 97, at shift 2
# Staff 50: works on day 98, at shift 2
# Staff 50: works on day 99, at shift 3
# Staff 50: works on day 100, at shift 4
# Staff 50: works on day 102, at shift 3
# Staff 50: works on day 103, at shift 3
# Staff 50: works on day 104, at shift 3
# Staff 50: works on day 105, at shift 3
# Staff 50: works on day 106, at shift 3
# Staff 50: works on day 107, at shift 3
# Staff 50: works on day 108, at shift 3
# Staff 50: works on day 109, at shift 2
# Staff 50: works on day 110, at shift 3
# Staff 50: works on day 111, at shift 3
# Staff 50: works on day 112, at shift 3
# Staff 50: works on day 113, at shift 3
# Staff 50: works on day 114, at shift 3
# Staff 50: works on day 115, at shift 3
# Staff 50: works on day 116, at shift 3
# Staff 50: works on day 117, at shift 3
# Staff 50: works on day 118, at shift 3
# Staff 50: works on day 119, at shift 3
# Staff 50: works on day 120, at shift 3
# Staff 50: works on day 121, at shift 3
# Staff 50: works on day 122, at shift 3
# Staff 50: works on day 123, at shift 3
# Staff 50: works on day 124, at shift 3
# Staff 50: works on day 125, at shift 3
# Staff 50: works on day 126, at shift 3
# Staff 50: works on day 127, at shift 3
# Staff 50: works on day 128, at shift 2
# Staff 50: works on day 129, at shift 3
# Staff 50: works on day 130, at shift 3
# Staff 50: works on day 131, at shift 2
# Staff 50: works on day 132, at shift 3
# Staff 50: works on day 133, at shift 3
# Staff 50: works on day 134, at shift 3
# Staff 50: works on day 135, at shift 3
# Staff 50: works on day 136, at shift 3
# Staff 50: works on day 137, at shift 3
# Staff 50: works on day 138, at shift 3
# Staff 50: works on day 139, at shift 3
# Staff 50: works on day 140, at shift 3
# Staff 50: works on day 141, at shift 3
# Staff 50: works on day 142, at shift 3
# Staff 50: works on day 143, at shift 3
# Staff 50: works on day 144, at shift 3
# Staff 50: works on day 145, at shift 3
# Staff 50: works on day 146, at shift 3
# Staff 50: works on day 147, at shift 3
# Staff 50: works on day 148, at shift 3
# Staff 50: works on day 149, at shift 3
# Staff 50: works on day 150, at shift 4
# Staff 50: works on day 152, at shift 3
# Staff 50: works on day 153, at shift 3
# Staff 50: works on day 154, at shift 3
# Staff 50: works on day 155, at shift 3
# Staff 50: works on day 156, at shift 3
# Staff 50: works on day 157, at shift 3
# Staff 50: works on day 158, at shift 3
# Staff 50: works on day 159, at shift 3
# Staff 50: works on day 160, at shift 3
# Staff 50: works on day 161, at shift 3
# Staff 50: works on day 162, at shift 3
# Staff 50: works on day 163, at shift 3
# Staff 50: works on day 164, at shift 3
# Staff 50: works on day 165, at shift 3
# Staff 50: works on day 166, at shift 3
# Staff 50: works on day 167, at shift 3
# Staff 50: works on day 168, at shift 3
# Staff 50: works on day 169, at shift 3
# Staff 50: works on day 170, at shift 3
# Staff 50: works on day 171, at shift 3
# Staff 50: works on day 172, at shift 3
# Staff 50: works on day 173, at shift 3
# Staff 50: works on day 174, at shift 3
# Staff 50: works on day 175, at shift 3
# Staff 50: works on day 176, at shift 3
# Staff 50: works on day 177, at shift 3
# Staff 50: works on day 178, at shift 3
# Staff 50: works on day 179, at shift 3
# Staff 50: works on day 180, at shift 3
# Staff 50: works on day 181, at shift 3
# Staff 50: works on day 182, at shift 3
# Staff 50: works on day 183, at shift 3
# Staff 50: works on day 184, at shift 3
# Staff 50: works on day 185, at shift 3
# Staff 50: works on day 186, at shift 3
# Staff 50: works on day 187, at shift 3
# Staff 50: works on day 188, at shift 3
# Staff 50: works on day 189, at shift 3
# Staff 50: works on day 190, at shift 3
# Staff 50: works on day 191, at shift 3
# Staff 50: works on day 192, at shift 2
# Staff 50: works on day 193, at shift 3
# Staff 50: works on day 194, at shift 3
# Staff 50: works on day 195, at shift 3
# Staff 50: works on day 196, at shift 3
# Staff 50: works on day 197, at shift 3
# Staff 50: works on day 198, at shift 3
# Staff 50: works on day 199, at shift 3
# Staff 50: works on day 200, at shift 4
# Staff 50: works on day 202, at shift 3
# Staff 50: works on day 203, at shift 3
# Staff 50: works on day 204, at shift 3
# Staff 50: works on day 205, at shift 3
# Staff 50: works on day 206, at shift 3
# Staff 50: works on day 207, at shift 3
# Staff 50: works on day 208, at shift 3
# Staff 50: works on day 209, at shift 3
# Staff 50: works on day 210, at shift 2
# Staff 50: works on day 211, at shift 3
# Staff 50: works on day 212, at shift 3
# Staff 50: works on day 213, at shift 3
# Staff 50: works on day 214, at shift 3
# Staff 50: works on day 215, at shift 3
# Staff 50: works on day 216, at shift 3
# Staff 50: works on day 217, at shift 3
# Staff 50: works on day 218, at shift 3
# Staff 50: works on day 219, at shift 3
# Staff 50: works on day 220, at shift 3
# Staff 50: works on day 221, at shift 3
# Staff 50: works on day 222, at shift 3
# Staff 50: works on day 223, at shift 3
# Staff 50: works on day 224, at shift 3
# Staff 50: works on day 225, at shift 3
# Staff 50: works on day 226, at shift 3
# Staff 50: works on day 227, at shift 3
# Staff 50: works on day 228, at shift 3
# Staff 50: works on day 229, at shift 3
# Staff 50: works on day 230, at shift 3
# Staff 50: works on day 231, at shift 3
# Staff 50: works on day 232, at shift 3
# Staff 50: works on day 233, at shift 3
# Staff 50: works on day 234, at shift 3
# Staff 50: works on day 235, at shift 3
# Staff 50: works on day 236, at shift 3
# Staff 50: works on day 237, at shift 3
# Staff 50: works on day 238, at shift 3
# Staff 50: works on day 239, at shift 3
# Staff 50: works on day 240, at shift 3
# Staff 50: works on day 241, at shift 3
# Staff 50: works on day 242, at shift 3
# Staff 50: works on day 243, at shift 3
# Staff 50: works on day 244, at shift 3
# Staff 50: works on day 245, at shift 3
# Staff 50: works on day 246, at shift 3
# Staff 50: works on day 247, at shift 3
# Staff 50: works on day 248, at shift 3
# Staff 50: works on day 249, at shift 3
# Staff 50: works on day 250, at shift 4
# Staff 50: works on day 252, at shift 3
# Staff 50: works on day 253, at shift 3
# Staff 50: works on day 254, at shift 3
# Staff 50: works on day 255, at shift 3
# Staff 50: works on day 256, at shift 3
# Staff 50: works on day 257, at shift 3
# Staff 50: works on day 258, at shift 3
# Staff 50: works on day 259, at shift 3
# Staff 50: works on day 260, at shift 3
# Staff 50: works on day 261, at shift 3
# Staff 50: works on day 262, at shift 3
# Staff 50: works on day 263, at shift 3
# Staff 50: works on day 264, at shift 3
# Staff 50: works on day 265, at shift 3
# Staff 50: works on day 266, at shift 3
# Staff 50: works on day 267, at shift 3
# Staff 50: works on day 268, at shift 3
# Staff 50: works on day 269, at shift 3
# Staff 50: works on day 270, at shift 3
# Staff 50: works on day 271, at shift 3
# Staff 50: works on day 272, at shift 3
# Staff 50: works on day 273, at shift 3
# Staff 50: works on day 274, at shift 3
# Staff 50: works on day 275, at shift 3
# Staff 50: works on day 276, at shift 3
# Staff 50: works on day 277, at shift 3
# Staff 50: works on day 278, at shift 3
# Staff 50: works on day 279, at shift 3
# Staff 50: works on day 280, at shift 3
# Staff 50: works on day 281, at shift 3
# Staff 50: works on day 282, at shift 3
# Staff 50: works on day 283, at shift 3
# Staff 50: works on day 284, at shift 3
# Staff 50: works on day 285, at shift 3
# Staff 50: works on day 286, at shift 3
# Staff 50: works on day 287, at shift 3
# Staff 50: works on day 288, at shift 3
# Staff 50: works on day 289, at shift 3
# Staff 50: works on day 290, at shift 3
# Staff 50: works on day 291, at shift 3
# Staff 50: works on day 292, at shift 3
# Staff 50: works on day 293, at shift 3
# Staff 50: works on day 294, at shift 3
# Staff 50: works on day 295, at shift 3
# Staff 50: works on day 296, at shift 3
# Staff 50: works on day 297, at shift 3
# Staff 50: works on day 298, at shift 3
# Staff 50: works on day 299, at shift 3
# Staff 50: works on day 300, at shift 4
# Staff 50: works on day 302, at shift 3
# Staff 50: works on day 303, at shift 3
# Staff 50: works on day 304, at shift 3
# Staff 50: works on day 305, at shift 3
# Staff 50: works on day 306, at shift 3
# Staff 50: works on day 307, at shift 3
# Staff 50: works on day 308, at shift 3
# Staff 50: works on day 309, at shift 3
# Staff 50: works on day 310, at shift 3
# Staff 50: works on day 311, at shift 3
# Staff 50: works on day 312, at shift 3
# Staff 50: works on day 313, at shift 3
# Staff 50: works on day 314, at shift 3
# Staff 50: works on day 315, at shift 3
# Staff 50: works on day 316, at shift 3
# Staff 50: works on day 317, at shift 3
# Staff 50: works on day 318, at shift 3
# Staff 50: works on day 319, at shift 3
# Staff 50: works on day 320, at shift 3
# Staff 50: works on day 321, at shift 3
# Staff 50: works on day 322, at shift 3
# Staff 50: works on day 323, at shift 3
# Staff 50: works on day 324, at shift 3
# Staff 50: works on day 325, at shift 3
# Staff 50: works on day 326, at shift 3
# Staff 50: works on day 327, at shift 3
# Staff 50: works on day 328, at shift 3
# Staff 50: works on day 329, at shift 3
# Staff 50: works on day 330, at shift 3
# Staff 50: works on day 331, at shift 3
# Staff 50: works on day 332, at shift 3
# Staff 50: works on day 333, at shift 3
# Staff 50: works on day 334, at shift 3
# Staff 50: works on day 335, at shift 3
# Staff 50: works on day 336, at shift 3
# Staff 50: works on day 337, at shift 3
# Staff 50: works on day 338, at shift 3
# Staff 50: works on day 339, at shift 3
# Staff 50: works on day 340, at shift 3
# Staff 50: works on day 341, at shift 3
# Staff 50: works on day 342, at shift 3
# Staff 50: works on day 343, at shift 3
# Staff 50: works on day 344, at shift 3
# Staff 50: works on day 345, at shift 3
# Staff 50: works on day 346, at shift 3
# Staff 50: works on day 347, at shift 3
# Staff 50: works on day 348, at shift 3
# Staff 50: works on day 349, at shift 3
# Staff 50: works on day 350, at shift 4
# Staff 50: works on day 352, at shift 3
# Staff 50: works on day 353, at shift 3
# Staff 50: works on day 354, at shift 3
# Staff 50: works on day 355, at shift 3
# Staff 50: works on day 356, at shift 3
# Staff 50: works on day 357, at shift 3
# Staff 50: works on day 358, at shift 3
# Staff 50: works on day 359, at shift 3
# Staff 50: works on day 360, at shift 3
# Staff 50: works on day 361, at shift 3
# Staff 50: works on day 362, at shift 3
# Staff 50: works on day 363, at shift 3
# Staff 50: works on day 364, at shift 3
# Staff 50: works on day 365, at shift 3
# Total execution time: 0.05934906005859375

# %% [markdown]
# # 3. Visualization

# %%
# column 5th is useless
S = np.full((N, D, 5), 0)

for staff in range(N):
    for day in range(D):
        for shift in range(4):
            S[staff, day, shift] = int(x[staff, day, shift])

shifts = np.array(["Morning", "Noon", "Afternoon", "Night"])
days = np.array([f"Day {day}" for day in range(1,D+1)])
day_shifts = np.sum(S, axis=0)
day_shifts_solution = pd.DataFrame(data=day_shifts[:, :4].T, index=shifts, columns=days)

# Visualize number staffs for each shift of day
day_shifts_solution.style.background_gradient(cmap='Pastel2')
# Out:
# <style  type="text/css" >
# #T_a73c1_row0_col0,#T_a73c1_row0_col1,#T_a73c1_row0_col2,#T_a73c1_row0_col3,#T_a73c1_row0_col4,#T_a73c1_row0_col5,#T_a73c1_row0_col6,#T_a73c1_row0_col7,#T_a73c1_row0_col8,#T_a73c1_row0_col9,#T_a73c1_row0_col10,#T_a73c1_row0_col11,#T_a73c1_row0_col12,#T_a73c1_row0_col13,#T_a73c1_row0_col14,#T_a73c1_row0_col15,#T_a73c1_row0_col16,#T_a73c1_row0_col17,#T_a73c1_row0_col18,#T_a73c1_row0_col19,#T_a73c1_row0_col20,#T_a73c1_row0_col21,#T_a73c1_row0_col22,#T_a73c1_row0_col23,#T_a73c1_row0_col24,#T_a73c1_row0_col25,#T_a73c1_row0_col26,#T_a73c1_row0_col27,#T_a73c1_row0_col28,#T_a73c1_row0_col29,#T_a73c1_row0_col30,#T_a73c1_row0_col31,#T_a73c1_row0_col32,#T_a73c1_row0_col33,#T_a73c1_row0_col34,#T_a73c1_row0_col35,#T_a73c1_row0_col36,#T_a73c1_row0_col37,#T_a73c1_row0_col38,#T_a73c1_row0_col39,#T_a73c1_row0_col40,#T_a73c1_row0_col41,#T_a73c1_row0_col42,#T_a73c1_row0_col43,#T_a73c1_row0_col44,#T_a73c1_row0_col45,#T_a73c1_row0_col46,#T_a73c1_row0_col47,#T_a73c1_row0_col48,#T_a73c1_row0_col49,#T_a73c1_row0_col50,#T_a73c1_row0_col51,#T_a73c1_row0_col52,#T_a73c1_row0_col53,#T_a73c1_row0_col54,#T_a73c1_row0_col55,#T_a73c1_row0_col56,#T_a73c1_row0_col57,#T_a73c1_row0_col58,#T_a73c1_row0_col59,#T_a73c1_row0_col60,#T_a73c1_row0_col61,#T_a73c1_row0_col62,#T_a73c1_row0_col63,#T_a73c1_row0_col64,#T_a73c1_row0_col65,#T_a73c1_row0_col66,#T_a73c1_row0_col67,#T_a73c1_row0_col68,#T_a73c1_row0_col69,#T_a73c1_row0_col70,#T_a73c1_row0_col71,#T_a73c1_row0_col72,#T_a73c1_row0_col73,#T_a73c1_row0_col74,#T_a73c1_row0_col75,#T_a73c1_row0_col76,#T_a73c1_row0_col77,#T_a73c1_row0_col78,#T_a73c1_row0_col79,#T_a73c1_row0_col80,#T_a73c1_row0_col81,#T_a73c1_row0_col82,#T_a73c1_row0_col83,#T_a73c1_row0_col84,#T_a73c1_row0_col85,#T_a73c1_row0_col86,#T_a73c1_row0_col87,#T_a73c1_row0_col88,#T_a73c1_row0_col89,#T_a73c1_row0_col90,#T_a73c1_row0_col91,#T_a73c1_row0_col92,#T_a73c1_row0_col93,#T_a73c1_row0_col94,#T_a73c1_row0_col95,#T_a73c1_row0_col96,#T_a73c1_row0_col97,#T_a73c1_row0_col98,#T_a73c1_row0_col99,#T_a73c1_row0_col100,#T_a73c1_row0_col101,#T_a73c1_row0_col102,#T_a73c1_row0_col103,#T_a73c1_row0_col104,#T_a73c1_row0_col105,#T_a73c1_row0_col106,#T_a73c1_row0_col107,#T_a73c1_row0_col108,#T_a73c1_row0_col109,#T_a73c1_row0_col110,#T_a73c1_row0_col111,#T_a73c1_row0_col112,#T_a73c1_row0_col113,#T_a73c1_row0_col114,#T_a73c1_row0_col115,#T_a73c1_row0_col116,#T_a73c1_row0_col117,#T_a73c1_row0_col118,#T_a73c1_row0_col119,#T_a73c1_row0_col120,#T_a73c1_row0_col121,#T_a73c1_row0_col122,#T_a73c1_row0_col123,#T_a73c1_row0_col124,#T_a73c1_row0_col125,#T_a73c1_row0_col126,#T_a73c1_row0_col127,#T_a73c1_row0_col128,#T_a73c1_row0_col129,#T_a73c1_row0_col130,#T_a73c1_row0_col131,#T_a73c1_row0_col132,#T_a73c1_row0_col133,#T_a73c1_row0_col134,#T_a73c1_row0_col135,#T_a73c1_row0_col136,#T_a73c1_row0_col137,#T_a73c1_row0_col138,#T_a73c1_row0_col139,#T_a73c1_row0_col140,#T_a73c1_row0_col141,#T_a73c1_row0_col142,#T_a73c1_row0_col143,#T_a73c1_row0_col144,#T_a73c1_row0_col145,#T_a73c1_row0_col146,#T_a73c1_row0_col147,#T_a73c1_row0_col148,#T_a73c1_row0_col149,#T_a73c1_row0_col150,#T_a73c1_row0_col151,#T_a73c1_row0_col152,#T_a73c1_row0_col153,#T_a73c1_row0_col154,#T_a73c1_row0_col155,#T_a73c1_row0_col156,#T_a73c1_row0_col157,#T_a73c1_row0_col158,#T_a73c1_row0_col159,#T_a73c1_row0_col160,#T_a73c1_row0_col161,#T_a73c1_row0_col162,#T_a73c1_row0_col163,#T_a73c1_row0_col164,#T_a73c1_row0_col165,#T_a73c1_row0_col166,#T_a73c1_row0_col167,#T_a73c1_row0_col168,#T_a73c1_row0_col169,#T_a73c1_row0_col170,#T_a73c1_row0_col171,#T_a73c1_row0_col172,#T_a73c1_row0_col173,#T_a73c1_row0_col174,#T_a73c1_row0_col175,#T_a73c1_row0_col176,#T_a73c1_row0_col177,#T_a73c1_row0_col178,#T_a73c1_row0_col179,#T_a73c1_row0_col180,#T_a73c1_row0_col181,#T_a73c1_row0_col182,#T_a73c1_row0_col183,#T_a73c1_row0_col184,#T_a73c1_row0_col185,#T_a73c1_row0_col186,#T_a73c1_row0_col187,#T_a73c1_row0_col188,#T_a73c1_row0_col189,#T_a73c1_row0_col190,#T_a73c1_row0_col191,#T_a73c1_row0_col192,#T_a73c1_row0_col193,#T_a73c1_row0_col194,#T_a73c1_row0_c ...

# %%
col = np.array([f"Staff {staff}" for staff in range(1,N+1)])
row = days
details_heu = np.full((D,N),"Rest")

for r in range(D):
  for c in range(N):
    for shift in range(1,5):
      if S[c,r,shift-1] == 1:
        details_heu[r,c] = shifts[shift-1]
        break

# Visualize details shift for each staff
pf_details_heu = pd.DataFrame(data = details_heu, index = row, columns = col)
pf_details_heu.style.applymap(status_color)
# Out:
# <style  type="text/css" >
# #T_2cddf_row0_col0,#T_2cddf_row1_col1,#T_2cddf_row2_col2,#T_2cddf_row3_col3,#T_2cddf_row4_col4,#T_2cddf_row5_col5,#T_2cddf_row6_col6,#T_2cddf_row7_col7,#T_2cddf_row8_col8,#T_2cddf_row9_col9,#T_2cddf_row10_col10,#T_2cddf_row11_col11,#T_2cddf_row12_col13,#T_2cddf_row13_col12,#T_2cddf_row14_col14,#T_2cddf_row15_col15,#T_2cddf_row16_col16,#T_2cddf_row17_col17,#T_2cddf_row18_col18,#T_2cddf_row19_col19,#T_2cddf_row20_col20,#T_2cddf_row21_col21,#T_2cddf_row22_col22,#T_2cddf_row23_col23,#T_2cddf_row24_col24,#T_2cddf_row25_col25,#T_2cddf_row26_col26,#T_2cddf_row27_col27,#T_2cddf_row28_col28,#T_2cddf_row29_col29,#T_2cddf_row30_col30,#T_2cddf_row31_col31,#T_2cddf_row32_col32,#T_2cddf_row33_col33,#T_2cddf_row34_col34,#T_2cddf_row35_col35,#T_2cddf_row36_col36,#T_2cddf_row37_col37,#T_2cddf_row38_col38,#T_2cddf_row39_col39,#T_2cddf_row40_col40,#T_2cddf_row41_col41,#T_2cddf_row42_col42,#T_2cddf_row43_col43,#T_2cddf_row44_col44,#T_2cddf_row45_col45,#T_2cddf_row46_col46,#T_2cddf_row47_col47,#T_2cddf_row48_col48,#T_2cddf_row49_col49,#T_2cddf_row50_col0,#T_2cddf_row51_col1,#T_2cddf_row52_col2,#T_2cddf_row53_col3,#T_2cddf_row54_col4,#T_2cddf_row55_col5,#T_2cddf_row56_col6,#T_2cddf_row57_col7,#T_2cddf_row58_col8,#T_2cddf_row59_col9,#T_2cddf_row60_col10,#T_2cddf_row61_col11,#T_2cddf_row62_col12,#T_2cddf_row63_col13,#T_2cddf_row64_col14,#T_2cddf_row65_col15,#T_2cddf_row66_col16,#T_2cddf_row67_col17,#T_2cddf_row68_col18,#T_2cddf_row69_col19,#T_2cddf_row70_col20,#T_2cddf_row71_col21,#T_2cddf_row72_col22,#T_2cddf_row73_col23,#T_2cddf_row74_col24,#T_2cddf_row75_col25,#T_2cddf_row76_col26,#T_2cddf_row77_col27,#T_2cddf_row78_col28,#T_2cddf_row79_col29,#T_2cddf_row80_col30,#T_2cddf_row81_col31,#T_2cddf_row82_col32,#T_2cddf_row83_col33,#T_2cddf_row84_col34,#T_2cddf_row85_col35,#T_2cddf_row86_col36,#T_2cddf_row87_col37,#T_2cddf_row88_col38,#T_2cddf_row89_col39,#T_2cddf_row90_col40,#T_2cddf_row91_col41,#T_2cddf_row92_col42,#T_2cddf_row93_col43,#T_2cddf_row94_col44,#T_2cddf_row95_col45,#T_2cddf_row96_col46,#T_2cddf_row97_col47,#T_2cddf_row98_col48,#T_2cddf_row99_col49,#T_2cddf_row100_col0,#T_2cddf_row101_col1,#T_2cddf_row102_col2,#T_2cddf_row103_col3,#T_2cddf_row104_col4,#T_2cddf_row105_col5,#T_2cddf_row106_col6,#T_2cddf_row107_col7,#T_2cddf_row108_col8,#T_2cddf_row109_col9,#T_2cddf_row110_col10,#T_2cddf_row111_col11,#T_2cddf_row112_col12,#T_2cddf_row113_col13,#T_2cddf_row114_col14,#T_2cddf_row115_col15,#T_2cddf_row116_col16,#T_2cddf_row117_col17,#T_2cddf_row118_col18,#T_2cddf_row119_col19,#T_2cddf_row120_col20,#T_2cddf_row121_col21,#T_2cddf_row122_col22,#T_2cddf_row123_col23,#T_2cddf_row124_col24,#T_2cddf_row125_col25,#T_2cddf_row126_col26,#T_2cddf_row127_col27,#T_2cddf_row128_col28,#T_2cddf_row129_col29,#T_2cddf_row130_col30,#T_2cddf_row131_col31,#T_2cddf_row132_col32,#T_2cddf_row133_col33,#T_2cddf_row134_col34,#T_2cddf_row135_col35,#T_2cddf_row136_col36,#T_2cddf_row137_col37,#T_2cddf_row138_col38,#T_2cddf_row139_col39,#T_2cddf_row140_col40,#T_2cddf_row141_col41,#T_2cddf_row142_col42,#T_2cddf_row143_col43,#T_2cddf_row144_col44,#T_2cddf_row145_col45,#T_2cddf_row146_col46,#T_2cddf_row147_col47,#T_2cddf_row148_col48,#T_2cddf_row149_col49,#T_2cddf_row150_col0,#T_2cddf_row151_col1,#T_2cddf_row152_col2,#T_2cddf_row153_col3,#T_2cddf_row154_col4,#T_2cddf_row155_col5,#T_2cddf_row156_col6,#T_2cddf_row157_col7,#T_2cddf_row158_col8,#T_2cddf_row159_col9,#T_2cddf_row160_col10,#T_2cddf_row161_col11,#T_2cddf_row162_col12,#T_2cddf_row163_col13,#T_2cddf_row164_col14,#T_2cddf_row165_col15,#T_2cddf_row166_col16,#T_2cddf_row167_col17,#T_2cddf_row168_col18,#T_2cddf_row169_col19,#T_2cddf_row170_col20,#T_2cddf_row171_col21,#T_2cddf_row172_col22,#T_2cddf_row173_col23,#T_2cddf_row174_col24,#T_2cddf_row175_col25,#T_2cddf_row176_col26,#T_2cddf_row177_col27,#T_2cddf_row178_col28,#T_2cddf_row179_col29,#T_2cddf_row180_col30,#T_2cddf_row181_col31,#T_2cddf_row182_col32,#T_2cddf_row183_col33,#T_2cddf_row184_col34,#T_2cddf_row185_col35,#T_2cddf_row186_col36,#T_2cddf_row187_col37,#T_2cddf_row18 ...
#             background-color:  Red;
#         }#T_2cddf_row0_col1,#T_2cddf_row0_col2,#T_2cddf_row0_col3,#T_2cddf_row0_col4,#T_2cddf_row
